# %% [markdown]
# ### Installing and importing libraries

# %%
pip install opencv-python==4.6.0.66
# Out:
# Collecting opencv-python==4.6.0.66Note: you may need to restart the kernel to use updated packages.
#
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
#      ---------------------------------------- 35.6/35.6 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\bhavya\anaconda3\lib\site-packages (from opencv-python==4.6.0.66) (1.23.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### To read the image

# %%
image = cv2.imread('horse.jpeg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ### Creating a new image by converting the original image to grayscale

# %%
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ### Inverting the new grayscale image

# %%
inv_img = 255 - gray_img
plt.imshow(cv2.cvtColor(inv_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ### Blurring the image by using the Gaussian Function in OpenCV

# %%
blurred = cv2.GaussianBlur(inv_img, (21,21), 0)

# %%
blurred
# Out:
# array([[ 47,  47,  48, ...,  46,  46,  46],
#        [ 47,  47,  48, ...,  46,  46,  46],
#        [ 47,  48,  48, ...,  47,  46,  46],
#        ...,
#        [159, 158, 158, ..., 120, 119, 118],
#        [158, 158, 157, ..., 120, 120, 119],
#        [158, 157, 157, ..., 120, 120, 119]], dtype=uint8)

# %% [markdown]
# ### The final step is to invert the blurred image, then we can easily convert the image into a pencil sketch

# %%
inv_blur = 255 - blurred
pencil_sketch = cv2.divide(gray_img, inv_blur, scale=256.0)
plt.imshow(cv2.cvtColor(pencil_sketch, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
